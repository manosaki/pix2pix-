# %%
# %tensorflow_version 1.14
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.14`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/"My Drive"/"Colab Notebooks"/"pix2pix-tensorflow-master"/"pix2pix-tensorflow-master"
# Out:
# /content/drive/My Drive/Colab Notebooks/pix2pix-tensorflow-master/pix2pix-tensorflow-master

# %%
! python pix2pix.py \
  --mode train \
  --output_dir facades_trains \
  --max_epochs 200 \
  --input_dir facades/train \
  --which_direction BtoA
# Out:
# WARNING:tensorflow:From pix2pix.py:540: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# aspect_ratio = 1.0
# batch_size = 1
# beta1 = 0.5
# checkpoint = None
# display_freq = 0
# flip = True
# gan_weight = 1.0
# input_dir = facades/train
# l1_weight = 100.0
# lab_colorization = False
# lr = 0.0002
# max_epochs = 200
# max_steps = None
# mode = train
# ndf = 64
# ngf = 64
# output_dir = facades_trains
# output_filetype = png
# progress_freq = 50
# save_freq = 5000
# scale_size = 286
# seed = 812422557
# separable_conv = False
# summary_freq = 100
# trace_freq = 0
# which_direction = BtoA
# WARNING:tensorflow:From pix2pix.py:258: string_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
! tensorboard --logdir=facades_train
# Out:
# TensorBoard 1.15.0 at http://dcdd0438ac47:6006/ (Press CTRL+C to quit)
# W0108 14:13:58.120620 139929201637120 plugin_event_accumulator.py:294] Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# W0108 14:13:58.123745 139929201637120 plugin_event_accumulator.py:302] Found more than one metagraph event per run. Overwriting the metagraph with the newest event.
# W0108 14:13:58.128731 139929201637120 plugin_event_accumulator.py:556] Detected out of order event.step likely caused by a TensorFlow restart. Purging 1296 expired tensor events from Tensorboard display between the previous step: 799 (timestamp: 1607045683.6887922) and current step: 0 (timestamp: 1607053973.7213523).
# ...

# %%
! python pix2pix.py \
  --mode test \
  --output_dir facades_test \
  --input_dir facades/val \
  --checkpoint facades_train
# Out:
# WARNING:tensorflow:From pix2pix.py:540: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# loaded lab_colorization = False
# loaded ndf = 64
# loaded ngf = 64
# loaded which_direction = BtoA
# aspect_ratio = 1.0
# batch_size = 1
# beta1 = 0.5
# checkpoint = facades_train
# display_freq = 0
# flip = False
# gan_weight = 1.0
# input_dir = facades/val
# l1_weight = 100.0
# lab_colorization = False
# lr = 0.0002
# max_epochs = None
# max_steps = None
# mode = test
# ndf = 64
# ngf = 64
# output_dir = facades_test
# output_filetype = png
# progress_freq = 50
# save_freq = 5000
# scale_size = 256
# seed = 1659748218
# separable_conv = False
# summary_freq = 100
# trace_freq = 0
# which_direction = BtoA
# WARNING:tensorflow:From pix2pix.py:258: string_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
# %cd /content/drive/"My Drive"/"Colab Notebooks"/"pix2pix-tensorflow-master"/"pix2pix-tensorflow-master-exp"
! python ./server/tools/export-checkpoint.py \
  --checkpoint facades_train \
  --output_file ./server/static/models/facades_BtoA0108_1.json #注意model資料夾要自己新增，不然檔案沒有資料夾存入
# Out:
# /content/drive/My Drive/Colab Notebooks/pix2pix-tensorflow-master/pix2pix-tensorflow-master-exp
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/pix2pix-tensorflow-master/pix2pix-tensorflow-master-exp/server/tools/dump_checkpoints/tensorflow_checkpoint_dumper.py:62: The name tf.train.NewCheckpointReader is deprecated. Please use tf.compat.v1.train.NewCheckpointReader instead.
#
# Writing variable generator_loss/Mean/ExponentialMovingAverage...
# Writing variable generator/encoder_8/conv2d/kernel/Adam...
# Writing variable generator/encoder_8/conv2d/kernel...
# Writing variable generator/encoder_8/batch_normalization/moving_mean...
# Writing variable generator/encoder_8/batch_normalization/gamma/Adam_1...
# Writing variable generator/encoder_8/batch_normalization/beta/Adam_1...
# Writing variable generator/encoder_8/batch_normalization/beta/Adam...
# Writing variable generator/encoder_8/batch_normalization/beta...
# ...

# %% [markdown]
# https://benpaodewoniu.github.io/2020/11/18/pix2pix-tensorflow0/
# https://github.com/affinelayer/pix2pix-tensorflow/tree/master/server#exporting
# https://github.com/yining1023/pix2pix_tensorflowjs_lite
